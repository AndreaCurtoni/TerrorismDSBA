# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
gtds = pd.read_csv("globalterrorismdb_0718dist.csv", encoding="ISO-8859-1")
pd.set_option("display.max_rows", None, "display.max_columns", None)
missing_value = gtds.isna().sum()
gtdsDropped = gtds
for i in range(0,missing_value.shape[0]-1,1):
    if ((missing_value.values[i]/len(gtds))>0.80):
        gtdsDropped = gtdsDropped.drop(columns=[missing_value.index[i]])
gtdsDropped.shape
# Out:
# (181691, 68)

# %%
gtdsDropped.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'extended', 'country',
#        'country_txt', 'region', 'region_txt', 'provstate', 'city', 'latitude',
#        'longitude', 'specificity', 'vicinity', 'location', 'summary', 'crit1',
#        'crit2', 'crit3', 'doubtterr', 'multiple', 'success', 'suicide',
#        'attacktype1', 'attacktype1_txt', 'targtype1', 'targtype1_txt',
#        'targsubtype1', 'targsubtype1_txt', 'corp1', 'target1', 'natlty1',
#        'natlty1_txt', 'gname', 'motive', 'guncertain1', 'individual', 'nperps',
#        'nperpcap', 'claimed', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'weapdetail', 'nkill', 'nkillus', 'nkillter',
#        'nwound', 'nwoundus', 'nwoundte', 'property', 'propextent',
#        'propextent_txt', 'propvalue', 'propcomment', 'ishostkid', 'ransom',
#        'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG', 'INT_IDEO',
#        'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object')

# %% [markdown]
# Capire gruppi terroristici più interessati ai riscatti
# Capire gruppi terroristici e i loro obiettivi (crit1,crti2,crti3)

# %%
ds = gtdsDropped[['gname','crit1','crit2','crit3']]
print(len(ds))
ds.head(5)
# Out:
# 181691
#                                 gname  crit1  crit2  crit3
# 0                              MANO-D      1      1      1
# 1  23rd of September Communist League      1      1      1
# 2                             Unknown      1      1      1
# 3                             Unknown      1      1      1
# 4                             Unknown      1      1      1

# %%
ds = ds.groupby(['gname']).agg('sum')
print(len(ds))
ds.sort_values(by='crit1', ascending=False).head(10)
# Out:
# 3537
#                                                   crit1  crit2  crit3
# gname
# Unknown                                           81007  82403  75908
# Taliban                                            7478   7471   6401
# Islamic State of Iraq and the Levant (ISIL)        5610   5575   4466
# Shining Path (SL)                                  4555   4552   4145
# Farabundo Marti National Liberation Front (FMLN)   3351   3349   2131
# Al-Shabaab                                         3283   3278   2103
# New People's Army (NPA)                            2760   2766   1901
# Irish Republican Army (IRA)                        2669   2637   1930
# Revolutionary Armed Forces of Colombia (FARC)      2487   2481   2115
# Boko Haram                                         2418   2414   2174

# %%
#plt.figure(figsize=(9,6))
#plt.subplot(131)
#plt.xticks(rotation=90)
#plt.bar(ds.index, ds['crit1'])
#plt.subplot(132)
#plt.bar(ds.index, ds['crit2'])
#plt.xticks(rotation=90)
#plt.subplot(133)
#plt.bar(ds.index, ds['crit3'])
#plt.xticks(rotation=90)
#plt.show()

# %%
ds = gtdsDropped[['gname','ransom']]
ds = ds.groupby(['gname'])['ransom'].value_counts()
len(ds)
ds = pd.DataFrame(ds)
ds = ds.rename(columns={'ransom':'counts'})
ds
# Out:
#                                                            counts
# gname                                              ransom
# 1 May                                               0.0        10
# 14th of December Command                            0.0         3
# 15th of September Liberation Legion                 0.0         1
# 16 January Organization for the Liberation of T...  0.0        24
# 19th of July Christian Resistance Brigade           0.0         1
# 1st of May Group                                    0.0         2
#                                                     1.0         2
# 2 April Group                                       0.0         6
# 20 December Movement (M-20)                         0.0        16
# 22 May 1948                                         0.0         1
# 23 May Democratic Alliance (Algeria)                0.0         1
# 23rd of September Communist League                  0.0        34
# ...

# %%
ds.reset_index()
#ds.pivot(index='gname', columns='ransom', values='counts')
#ds
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gname'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-9822ba3e9c3f> in <module>
#       1 ds.reset_index()
# ...
